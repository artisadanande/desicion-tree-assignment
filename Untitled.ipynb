# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Companydata.csv')

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
df.isnull().any()
# Out:
# Sales          False
# CompPrice      False
# Income         False
# Advertising    False
# Population     False
# Price          False
# ShelveLoc      False
# Age            False
# Education      False
# Urban          False
# US             False
# dtype: bool

# %%
df.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc       object
# Age              int64
# Education        int64
# Urban           object
# US              object
# dtype: object

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df['ShelveLoc'],class_names = pd.factorize(df['ShelveLoc'])

# %%
print(class_names)
# Out:
# Index(['Bad', 'Good', 'Medium'], dtype='object')

# %%
df['Urban'],class_names2=pd.factorize(df['Urban'])

# %%
print(class_names2)
# Out:
# Index(['Yes', 'No'], dtype='object')

# %%
df['US'].replace(to_replace=['Yes', 'No'],value= ['0', '1'], inplace=True)

# %%
df.US
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: US, Length: 400, dtype: object

# %%
print(df['US'].unique())
# Out:
# ['0' '1']

# %%
df['Sales'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Sales.describe()
# Out:
# count    400.000000
# mean       7.496325
# std        2.824115
# min        0.000000
# 25%        5.390000
# 50%        7.490000
# 75%        9.320000
# max       16.270000
# Name: Sales, dtype: float64

# %%
category = pd.cut(df.Sales,bins=[0,5.39,9.32,17],labels=['low','moderate','high'])

# %%
df.insert(0,'Sales_Group',category)

# %%
df.drop(['Sales'],axis = 1, inplace = True)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df['Sales_Group'].unique()
df.Sales_Group.value_counts()
# Out:
# moderate    201
# high         99
# low          99
# Name: Sales_Group, dtype: int64

# %%
colnames = list(df.columns)
colnames
predictors = colnames[1:]

# %%
target = colnames[0]

# %%
import numpy as np

# %%
df['is_train'] = np.random.uniform(0, 1, len(df))<= 0.75
df['is_train']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399    False
# Name: is_train, Length: 400, dtype: bool

# %%
train,test = df[df['is_train'] == True],df[df['is_train']==False]

# %%
train.shape
# Out:
# (296, 12)

# %%
test.shape
# Out:
# (104, 12)

# %%
from sklearn.tree import  DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion = 'entropy')

# %%
model.fit(train[predictors],train[target])
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
preds = model.predict(test[predictors])

# %%
preds
# Out:
# array(['low', 'high', 'high', 'low', 'moderate', 'high', 'low',
#        'moderate', 'moderate', 'low', 'moderate', 'moderate', 'moderate',
#        'moderate', 'moderate', 'moderate', 'high', 'moderate', 'high',
#        'low', 'low', 'moderate', 'moderate', 'moderate', 'moderate',
#        'low', 'moderate', 'low', 'high', 'low', 'moderate', 'high',
#        'moderate', 'high', 'moderate', 'low', 'moderate', 'high',
#        'moderate', 'low', 'moderate', 'high', 'high', 'high', 'moderate',
#        'high', 'moderate', 'high', 'high', 'low', 'high', 'high',
#        'moderate', 'moderate', 'high', 'low', 'low', 'moderate', 'low',
#        'low', 'low', 'moderate', 'low', 'high', 'low', 'moderate', 'low',
#        'moderate', 'moderate', 'moderate', 'moderate', 'low', 'low',
#        'low', 'moderate', 'moderate', 'moderate', 'high', 'low',
#        'moderate', 'moderate', 'low', 'moderate', 'moderate', 'high',
#        'moderate', 'moderate', 'high', 'low', 'moderate', 'moderate',
#        'high', 'moderate', 'low', 'moderate', 'high', 'low', 'high',
#        'low', 'moderate', 'moderate', 'moderate', 'moderate', 'moderate'],
#       dtype=object)

# %%
pd.Series(preds).value_counts()
# Out:
# moderate    50
# low         29
# high        25
# dtype: int64

# %%
pd.crosstab(test[target],preds)
# Out:
# col_0        high  low  moderate
# Sales_Group
# low             1   19        12
# moderate       10    9        31
# high           14    0         7

# %%
np.mean(train.Sales_Group == model.predict(train[predictors]))
# Out:
# 1.0

# %%
np.mean(preds==test.Sales_Group)
# Out:
# 0.6153846153846154
